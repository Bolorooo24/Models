# %%
import pandas as pd
import numpy as np

# %%
pip install kagglehub

# %%
import kagglehub

# %%
import shutil

# %%
path = kagglehub.dataset_download("stefanoleone992/fifa-22-complete-player-dataset")
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 109M/109M [00:13<00:00, 8.39MB/s]
# Extracting model files...

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\b.bolormaa5450\.cache\kagglehub\datasets\stefanoleone992\fifa-22-complete-player-dataset\versions\3

# %%
src_path = r'C:\Users\b.bolormaa5450\.cache\kagglehub\datasets\stefanoleone992\fifa-22-complete-player-dataset\versions\3'
file_path = r'C:\Users\b.bolormaa5450\Desktop\Python\Anaconda\Research_model\dataset'
shutil.move(src_path, file_path)

# %%
players= pd.read_csv("dataset/3/players_22.csv")
players.head()
# Out:
# C:\Users\b.bolormaa5450\AppData\Local\Temp\ipykernel_31008\3939715176.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   players= pd.read_csv("dataset/3/players_22.csv")
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# ...

# %%
players
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
features  = ["overall", "potential", "value_eur", "wage_eur", "age"]
features
# Out:
# ['overall', 'potential', 'value_eur', 'wage_eur', 'age']

# %%
players = players.dropna(subset=features)
players
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
data = players[features].copy()

# %%
data
# Out:
#        overall  potential    value_eur  wage_eur  age
# 0           93         93   78000000.0  320000.0   34
# 1           92         92  119500000.0  270000.0   32
# 2           91         91   45000000.0  270000.0   36
# 3           91         91  129000000.0  270000.0   29
# 4           91         91  125500000.0  350000.0   30
# ...        ...        ...          ...       ...  ...
# 19234       47         52      70000.0    1000.0   22
# 19235       47         59     110000.0     500.0   19
# 19236       47         55     100000.0     500.0   21
# 19237       47         60     110000.0     500.0   19
# 19238       47         60     110000.0     500.0   19
#
# [19165 rows x 5 columns]

# %%
# 1. scale the data (range 1 to 10)
# 2. initialize random centroids
# 3. label each data point
# 4. update centroids
# 5. repeats steps 3 and 4 until centroids stop changing

# %%
data = ((data - data.min())/(data.max() - data.min()))*9 + 1

# %%
data.describe()
# Out:
#             overall     potential     value_eur      wage_eur           age
# count  19165.000000  19165.000000  19165.000000  19165.000000  19165.000000
# mean       4.670472      5.319998      1.131826      1.219443      4.063345
# std        1.346635      1.191076      0.353229      0.501528      1.575838
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.739130      4.521739      1.021620      1.012876      2.666667
# 50%        4.717391      5.304348      1.044817      1.064378      4.000000
# 75%        5.500000      6.086957      1.092370      1.193133      5.333333
# max       10.000000     10.000000     10.000000     10.000000     10.000000

# %%
data.head()
# Out:
#      overall  potential  value_eur   wage_eur       age
# 0  10.000000   9.608696   4.618307   9.227468  7.000000
# 1   9.804348   9.413043   6.543654   7.939914  6.333333
# 2   9.608696   9.217391   3.087308   7.939914  7.666667
# 3   9.608696   9.217391   6.984396   7.939914  5.333333
# 4   9.608696   9.217391   6.822018  10.000000  5.666667

# %%
def random_centroids(data, k):
    centroids = []
    for i in range(k):
        centroid = data.apply(lambda x: float(x.sample()))
        centroids.append(centroid)
    return pd.concat(centroids, axis=1)

# %%
centroids = random_centroids(data, 5)
centroids
# Out:
# C:\Users\b.bolormaa5450\AppData\Local\Temp\ipykernel_31008\2429723876.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   centroid = data.apply(lambda x: float(x.sample()))
#                   0         1         2         3         4
# overall    2.760870  7.847826  1.586957  3.152174  7.260870
# potential  4.326087  4.326087  4.130435  7.065217  3.934783
# value_eur  1.055255  1.015820  1.008861  1.078452  1.018140
# wage_eur   1.000000  1.002575  1.296137  1.424893  1.296137
# age        6.333333  2.000000  1.000000  5.666667  4.666667

# %%
def get_labels(data, centroids):
    distances = centroids.apply(lambda x: np.sqrt(((data-x) ** 2).sum(axis=1)))
    return distances.idxmin(axis=1)

# %%
distances
# Out:
#                0          1          2          3          4
# 0      12.694171  11.754343  14.585086  11.338013  11.000353
# 1      12.400510  11.276813  14.094312  11.068970  10.673775
# 2      11.175286  10.561930  13.532538   9.838675   9.530974
# 3      12.455308  11.040254  13.742270  11.124537  10.658268
# 4      13.620484  12.455342  14.884664  12.362829  11.994184
# ...          ...        ...        ...        ...        ...
# 19234   4.660206   7.442838   3.300617   6.475321   6.897030
# 19235   4.874085   6.983449   1.676396   5.928208   6.881459
# 19236   4.602126   7.208964   2.652921   6.143513   6.810803
# 19237   4.822766   6.947728   1.545712   5.794323   6.856380
# 19238   4.822766   6.947728   1.545712   5.794323   6.856380
#
# [19165 rows x 5 columns]

# %%
labels = get_labels(data, centroids)

# %%
labels.value_counts()
# Out:
# 4    6185
# 0    4989
# 2    4417
# 3    2423
# 1    1151
# Name: count, dtype: int64

# %%
def new_centroids(data, labels, k):
    return data.groupby(labels).apply(lambda x: np.exp(np.log(x).mean())).T

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
def plot_clusters(data, labels, centroids, iteration):
    pca = PCA(n_components = 2)
    data_2d = pca.fit_transform(data)
    centroids_2d = pca.transform(centroids.T)
    clear_output(wait= True)
    plt.title(f'Interation {iteration}')
    plt.scatter(x = data_2d[:, 0], y = data_2d[:, 1], c=labels)
    plt.scatter(x = centroids_2d[:, 0], y = centroids_2d[:, 1])
    plt.show()

# %%
max_iterations = 100
k = 3

centroids = random_centroids(data, k)
old_centroids = pd.DataFrame()
iteration = 1

while iteration < max_iterations and not centroids.equals(old_centroids):
    old_centroids = centroids
    labels = get_labels(data, centroids)
    centroids = new_centroids(data, labels, k)
    plot_clusters(data, labels, centroids, iteration)
    iteration += 1

# %%
centroids
# Out:
#                   0         1         2
# overall    4.781960  5.807503  3.205672
# potential  4.506813  6.497870  4.930905
# value_eur  1.044909  1.285685  1.026655
# wage_eur   1.118498  1.420500  1.028564
# age        5.467648  3.598215  2.514741

# %%
players[labels == 4][["short_name"] + features]
# Out:
# Empty DataFrame
# Columns: [short_name, overall, potential, value_eur, wage_eur, age]
# Index: []

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(3)
kmeans.fit(data)
# Out:
# c:\users\b.bolormaa5450\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
centroids = kmeans.cluster_centers_

# %%
pd.DataFrame(centroids, columns = features).T
# Out:
#                   0         1         2
# overall    3.602247  4.800409  6.234851
# potential  5.208414  4.503433  6.623743
# value_eur  1.035908  1.039977  1.414491
# wage_eur   1.040100  1.112740  1.658628
# age        2.712566  5.608753  4.144340
